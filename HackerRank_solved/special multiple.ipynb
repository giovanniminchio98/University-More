# %%
import math
import os
import random
import re
import sys

#
# Complete the 'solve' function below.
#
# The function is expected to return a STRING.
# The function accepts INTEGER n as parameter.
#

# best solution 30/30
def solve(n):
    elem =1
    nn = bin(elem)[2:]
    while True:
        if (int(nn)*9)%n ==0:
            print(nn)
            return str((int(nn)*9))
        elem+=1
        nn = bin(elem)[2:]

# naive solution 27/30
def solve(n):
    lista = list(range(1,100001))
    lista = [bin(x)[2:] for x in lista]
    for elem in lista:
        if int(int(elem)*9)%n ==0:
            return str(int(int(elem)*9))

def solve(n):
    numero = 9
    original=9
    cnt=0
    change=1
    next_cnt =1
    while True:
        if numero >= n and numero%n==0:
            return str(numero)
        
        if cnt == next_cnt:
            original = original*10
            numero = original
            cnt=0
            next_cnt+=1
        
        try:
            numero = original + int('9'*cnt)
        except:
            a=1
        cnt+=1
